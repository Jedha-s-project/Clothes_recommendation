# %%
import pandas as pd

# %%
datatest = pd.read_excel("Clothes_bdd.xlsx")
datatest
# Out:
#     Unnamed: 0      Unnamed: 1  \
# 0          NaN            Noms
# 1          NaN     Tee-shirt_1
# 2          NaN          Pull_1
# 3          NaN          Pull_2
# 4          NaN         Veste_1
# 5          NaN        Gillet_1
# 6          NaN     Robe_pull_1
# 7          NaN         Veste_2
# 8          NaN           Short
# 9          NaN       Chemisier
# 10         NaN     Tee-shirt_3
# 11         NaN     Chemisier_2
# 12         NaN         Short_2
# 13         NaN     Jupe-longue
# 14         NaN  Robe-de-soirée
# 15         NaN   Jupe-courte_1
# 16         NaN      Pantalon_1
# 17         NaN          Jean_1
# 18         NaN     Debardeur_1
# 19         NaN     Debardeur_2
# 20         NaN     Debardeur_3
#
#    C:\Users\fanny\OneDrive\Bureau\Jedha\Final_project  \
# 0                                              Photos
# 1   C:\Users\fanny\OneDrive\Bureau\Jedha\Final_pro...
# 2   C:\Users\fanny\OneDrive\Bureau\Jedha\Final_pro...
# ...
