# %% [markdown]
# ### Prep

# %%
# Import of librairies
import pandas as pd
import sklearn
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer

# %%
# Import of data
df_clothes = pd.read_excel("./Dataset/Clothes_table.xlsx")
df_clothes
# Out:
#      id_clothes   category                                        description
# 0      tshirt_1     tshirt  J'ai acheté ce tshirt pour les beaux jours, po...
# 1        pull_1       pull  J'ai acheté ce pull pour le porter en mi saiso...
# 2        pull_2       pull  J'aime le côté rock de ce pull. J'ai envie de ...
# 3       veste_1      veste  Je voulais un classique rock intemporel, que l...
# 4       gilet_1      gilet  J'aime le côté ethnique et loose de ce gilet. ...
# 5        robe_1       robe  J'ai acheté cette robe pour me sentir féminine...
# 6       veste_2      veste  Je voulais une veste en jean légère, apportant...
# 7       short_1      short  Je voulais un short en jean pour me sentir à l...
# 8      blouse_1     blouse  Je voulais une chemise classique mais conforta...
# 9      tshirt_2     tshirt  Je cherchais un tshirt avec capuche pour le cô...
# 10     blouse_2     blouse  J'ai acheté cette blouse pour avoir des tenues...
# ...

# %%
df_mood = pd.read_excel("./Dataset/Mood_table.xlsx")
df_mood
# Out:
#     id_mood                                           day_mood
# 0    mood_0  Je suis fatiguée, et je sais que j'ai une gros...
# 1    mood_1  Je suis en pleine forme pour mon entretien ave...
# 2    mood_2  Il fait froid dehors, j'ai trop envie de reste...
# 3    mood_3  Il fait trop beau et chaud, j'ai trop hâte d'a...
# 4    mood_4  Je suis trop contente, aujourd'hui je vois Clé...
# 5    mood_5  Journée shopping avec les copines, ça va être ...
# 6    mood_6                    Trop dur de se lever ce matin….
# 7    mood_7  J'ai une réunion tout à l'heure, je suis trop ...
# 8    mood_8  J'ai bien dormi, je me sens reposée, je sens q...
# 9    mood_9  Il pleut, je suis crevée, et j'ai loupé mon ré...
# 10  mood_10  Ce boulot me soule, j'en ai trop marre, j'ai e...
# 11  mood_11  Hâte d'aller au travail et de raconter mon wee...
# 12  mood_12                                     J'ai trop faim
# 13  mood_13              Je suis complétement à la bourre !!!!
# ...

# %%
df_true_clothes = pd.read_excel("./Dataset/true_clothes.xlsx")
df_true_clothes = df_true_clothes.rename(columns={"Unnamed: 0": "mood_id"})
df_true_clothes
# Out:
#    mood_id first_true_clothe sedcond_true_clothe third_true_clothe  \
# 0   mood_1          blouse_5            blouse_1          blouse_2
# 1   mood_4            robe_7              robe_5            robe_6
# 2  mood_18        pantalon_1             gilet_3            pull_4
# 3  mood_26        pantalon_6          pantalon_7          tshirt_5
# 4  mood_22       debardeur_5         debardeur_7            pull_4
# 5   mood_3          tshirt_2             short_1       debardeur_8
#
#   fourth_true_clothe
# 0           tshirt_4
# 1        debardeur_4
# 2         pantalon_3
# 3         pantalon_5
# 4        debardeur_6
# 5           blouse_6

# %% [markdown]
# ### Model 1

# %%
model = SentenceTransformer("stsb-xlm-r-multilingual")

# %%
df_clothes[[[[[["mood_18_tristesse", "mood_4_seduction", "mood_26_fatigue_maison", "mood_1_travail", "mood_22_sorties_amis" ,"mood_3_sorties_detente"]]]]]] = ""

# %%
for i in range (len(df_clothes)) :
    x= model.encode(df_mood.loc[18]["day_mood"])
    y = model.encode(df_clothes.loc[i]["description"])
    X = x.reshape(1, -1)
    Y = y.reshape(1, -1)
    df_clothes.loc[i]["mood_18_tristesse"] = sklearn.metrics.pairwise.cosine_similarity(X,Y)
df_clothes
# Out:
#      id_clothes   category                                        description  \
# 0      tshirt_1     tshirt  J'ai acheté ce tshirt pour les beaux jours, po...
# 1        pull_1       pull  J'ai acheté ce pull pour le porter en mi saiso...
# 2        pull_2       pull  J'aime le côté rock de ce pull. J'ai envie de ...
# 3       veste_1      veste  Je voulais un classique rock intemporel, que l...
# 4       gilet_1      gilet  J'aime le côté ethnique et loose de ce gilet. ...
# 5        robe_1       robe  J'ai acheté cette robe pour me sentir féminine...
# 6       veste_2      veste  Je voulais une veste en jean légère, apportant...
# 7       short_1      short  Je voulais un short en jean pour me sentir à l...
# 8      blouse_1     blouse  Je voulais une chemise classique mais conforta...
# 9      tshirt_2     tshirt  Je cherchais un tshirt avec capuche pour le cô...
# 10     blouse_2     blouse  J'ai acheté cette blouse pour avoir des tenues...
# ...

# %%
for i in range (len(df_clothes)) :
    x= model.encode(df_mood.loc[4]["day_mood"])
    y = model.encode(df_clothes.loc[i]["description"])
    X = x.reshape(1, -1)
    Y = y.reshape(1, -1)
    df_clothes.loc[i]["mood_4_seduction"] = sklearn.metrics.pairwise.cosine_similarity(X,Y)

# %%
for i in range (len(df_clothes)) :
    x= model.encode(df_mood.loc[26]["day_mood"])
    y = model.encode(df_clothes.loc[i]["description"])
    X = x.reshape(1, -1)
    Y = y.reshape(1, -1)
    df_clothes.loc[i]["mood_26_fatigue_maison"] = sklearn.metrics.pairwise.cosine_similarity(X,Y)

# %%
for i in range (len(df_clothes)) :
    x= model.encode(df_mood.loc[1]["day_mood"])
    y = model.encode(df_clothes.loc[i]["description"])
    X = x.reshape(1, -1)
    Y = y.reshape(1, -1)
    df_clothes.loc[i]["mood_1_travail"] = sklearn.metrics.pairwise.cosine_similarity(X,Y)

# %%
for i in range (len(df_clothes)) :
    x= model.encode(df_mood.loc[22]["day_mood"])
    y = model.encode(df_clothes.loc[i]["description"])
    X = x.reshape(1, -1)
    Y = y.reshape(1, -1)
    df_clothes.loc[i]["mood_22_sorties_amis"] = sklearn.metrics.pairwise.cosine_similarity(X,Y)

# %%
for i in range (len(df_clothes)) :
    x= model.encode(df_mood.loc[3]["day_mood"])
    y = model.encode(df_clothes.loc[i]["description"])
    X = x.reshape(1, -1)
    Y = y.reshape(1, -1)
    df_clothes.loc[i]["mood_3_sorties_detente"] = sklearn.metrics.pairwise.cosine_similarity(X,Y)
df_clothes
# Out:
#      id_clothes   category                                        description  \
# 0      tshirt_1     tshirt  J'ai acheté ce tshirt pour les beaux jours, po...
# 1        pull_1       pull  J'ai acheté ce pull pour le porter en mi saiso...
# 2        pull_2       pull  J'aime le côté rock de ce pull. J'ai envie de ...
# 3       veste_1      veste  Je voulais un classique rock intemporel, que l...
# 4       gilet_1      gilet  J'aime le côté ethnique et loose de ce gilet. ...
# 5        robe_1       robe  J'ai acheté cette robe pour me sentir féminine...
# 6       veste_2      veste  Je voulais une veste en jean légère, apportant...
# 7       short_1      short  Je voulais un short en jean pour me sentir à l...
# 8      blouse_1     blouse  Je voulais une chemise classique mais conforta...
# 9      tshirt_2     tshirt  Je cherchais un tshirt avec capuche pour le cô...
# 10     blouse_2     blouse  J'ai acheté cette blouse pour avoir des tenues...
# ...

# %%
y_pred_mood_18_tristesse = df_clothes.sort_values(by=['mood_18_tristesse'], ascending=False).head(4)["id_clothes"]
y_pred_mood_18_tristesse
# Out:
# 9        tshirt_2
# 33    debardeur_6
# 3         veste_1
# 18    debardeur_2
# Name: id_clothes, dtype: object

# %%
y_pred_mood_4_seduction = df_clothes.sort_values(by=['mood_4_seduction'], ascending=False).head(4)["id_clothes"]
y_pred_mood_4_seduction
# Out:
# 34    debardeur_7
# 30         robe_6
# 27         robe_4
# 28        gilet_2
# Name: id_clothes, dtype: object

# %%
y_pred_mood_26_fatigue_maison= df_clothes.sort_values(by=['mood_26_fatigue_maison'], ascending=False).head(4)["id_clothes"]
y_pred_mood_26_fatigue_maison
# Out:
# 33    debardeur_6
# 12         jupe_1
# 18    debardeur_2
# 9        tshirt_2
# Name: id_clothes, dtype: object

# %%
y_pred_mood_1_travail = df_clothes.sort_values(by=['mood_1_travail'], ascending=False).head(4)["id_clothes"]
y_pred_mood_1_travail
# Out:
# 46      blouse_5
# 15    pantalon_1
# 21    pantalon_3
# 8       blouse_1
# Name: id_clothes, dtype: object

# %%
y_pred_mood_22_sorties_amis = df_clothes.sort_values(by=['mood_22_sorties_amis'], ascending=False).head(4)["id_clothes"]
y_pred_mood_22_sorties_amis
# Out:
# 33    debardeur_6
# 47       blouse_6
# 9        tshirt_2
# 18    debardeur_2
# Name: id_clothes, dtype: object

# %%
y_pred_df_mood_3_sorties_detente = df_clothes.sort_values(by=['mood_3_sorties_detente'], ascending=False).head(4)["id_clothes"]
y_pred_df_mood_3_sorties_detente
# Out:
# 27         robe_4
# 30         robe_6
# 18    debardeur_2
# 35    debardeur_8
# Name: id_clothes, dtype: object

# %%
y_true_mood_1_travail = df_true_clothes.iloc[0, :]
y_true_mood_1_travail
# Out:
# mood_id                  mood_1
# first_true_clothe      blouse_5
# sedcond_true_clothe    blouse_1
# third_true_clothe      blouse_2
# fourth_true_clothe     tshirt_4
# Name: 0, dtype: object

# %%
y_true_mood_4_seduction = df_true_clothes.iloc[1, :]
y_true_mood_4_seduction
# Out:
# mood_id                     mood_4
# first_true_clothe           robe_7
# sedcond_true_clothe         robe_5
# third_true_clothe           robe_6
# fourth_true_clothe     debardeur_4
# Name: 1, dtype: object

# %%
y_true_mood_18_tristesse = df_true_clothes.iloc[2, :]
y_true_mood_18_tristesse
# Out:
# mood_id                   mood_18
# first_true_clothe      pantalon_1
# sedcond_true_clothe       gilet_3
# third_true_clothe          pull_4
# fourth_true_clothe     pantalon_3
# Name: 2, dtype: object

# %%
y_true_mood_26_fatigue_maison = df_true_clothes.iloc[3, :]
y_true_mood_26_fatigue_maison
# Out:
# mood_id                   mood_26
# first_true_clothe      pantalon_6
# sedcond_true_clothe    pantalon_7
# third_true_clothe        tshirt_5
# fourth_true_clothe     pantalon_5
# Name: 3, dtype: object

# %%
y_true_mood_22_sorties_amis = df_true_clothes.iloc[4, :]
y_true_mood_22_sorties_amis
# Out:
# mood_id                    mood_22
# first_true_clothe      debardeur_5
# sedcond_true_clothe    debardeur_7
# third_true_clothe           pull_4
# fourth_true_clothe     debardeur_6
# Name: 4, dtype: object

# %%
y_true_mood_3_sorties_detente = df_true_clothes.iloc[5, :]
y_true_mood_3_sorties_detente
# Out:
# mood_id                     mood_3
# first_true_clothe         tshirt_2
# sedcond_true_clothe        short_1
# third_true_clothe      debardeur_8
# fourth_true_clothe        blouse_6
# Name: 5, dtype: object

# %%
score_mood1 = 0
for i in (y_true_mood_1_travail.index[1:]) :
    x = y_true_mood_1_travail[1:][i]
    for e in (y_pred_mood_1_travail.index) :
        if x == y_pred_mood_1_travail[e] :
            score_mood1 = score_mood1+1
print(score_mood1)
# Out:
# 2

# %%
score_mood4 = 0
for i in (y_true_mood_4_seduction.index[1:]) :
    x = y_true_mood_4_seduction[1:][i]
    for e in (y_pred_mood_4_seduction.index) :
        if x == y_pred_mood_4_seduction[e] :
            score_mood4 = score_mood4+1
print(score_mood4)
# Out:
# 1

# %%
score_mood18 = 0
for i in (y_true_mood_18_tristesse.index[1:]) :
    x = y_true_mood_18_tristesse[1:][i]
    for e in (y_pred_mood_18_tristesse.index) :
        if x == y_pred_mood_18_tristesse[e] :
            score_mood18 = score_mood18+1
print(score_mood18)
# Out:
# 0

# %%
score_mood26 = 0
for i in (y_true_mood_26_fatigue_maison.index[1:]) :
    x = y_true_mood_26_fatigue_maison[1:][i]
    for e in (y_pred_mood_26_fatigue_maison.index) :
        if x == y_pred_mood_26_fatigue_maison[e] :
            score_mood26 = score_mood26+1
print(score_mood26)
# Out:
# 0

# %%
score_mood22 = 0
for i in (y_true_mood_22_sorties_amis.index[1:]) :
    x = y_true_mood_22_sorties_amis[1:][i]
    for e in (y_pred_mood_22_sorties_amis.index) :
        if x == y_pred_mood_22_sorties_amis[e] :
            score_mood22 = score_mood22+1
print(score_mood22)
# Out:
# 1

# %%
score_mood3 = 0
for i in (y_true_mood_3_sorties_detente.index[1:]) :
    x = y_true_mood_3_sorties_detente[1:][i]
    for e in (y_pred_df_mood_3_sorties_detente.index) :
        if x == y_pred_df_mood_3_sorties_detente[e] :
            score_mood3 = score_mood3+1
print(score_mood3)
# Out:
# 1

# %%
score_total = (score_mood3 + score_mood22 +score_mood26 +score_mood18 +score_mood4 +score_mood1)/24
score_total
# Out:
# 0.20833333333333334

# %% [markdown]
# ### Model 2

# %%
model2 = SentenceTransformer("distiluse-base-multilingual-cased-v1")

# %%
df_clothes_model_2 = pd.read_excel("./Dataset/Clothes_table.xlsx")
df_clothes_model_2[[[[[["mood_18_tristesse", "mood_4_seduction", "mood_26_fatigue_maison", "mood_1_travail", "mood_22_sorties_amis" ,"mood_3_sorties_detente"]]]]]] = ""
# Out:
#      id_clothes   category                                        description  \
# 0      tshirt_1     tshirt  J'ai acheté ce tshirt pour les beaux jours, po...
# 1        pull_1       pull  J'ai acheté ce pull pour le porter en mi saiso...
# 2        pull_2       pull  J'aime le côté rock de ce pull. J'ai envie de ...
# 3       veste_1      veste  Je voulais un classique rock intemporel, que l...
# 4       gilet_1      gilet  J'aime le côté ethnique et loose de ce gilet. ...
# 5        robe_1       robe  J'ai acheté cette robe pour me sentir féminine...
# 6       veste_2      veste  Je voulais une veste en jean légère, apportant...
# 7       short_1      short  Je voulais un short en jean pour me sentir à l...
# 8      blouse_1     blouse  Je voulais une chemise classique mais conforta...
# 9      tshirt_2     tshirt  Je cherchais un tshirt avec capuche pour le cô...
# 10     blouse_2     blouse  J'ai acheté cette blouse pour avoir des tenues...
# ...

# %%
for i in range (len(df_clothes_model_2)) :
    x= model2.encode(df_mood.loc[18]["day_mood"])
    y = model2.encode(df_clothes_model_2.loc[i]["description"])
    X = x.reshape(1, -1)
    Y = y.reshape(1, -1)
    df_clothes_model_2.loc[i]["mood_18_tristesse"] = sklearn.metrics.pairwise.cosine_similarity(X,Y)

for i in range (len(df_clothes_model_2)) :
    x= model2.encode(df_mood.loc[4]["day_mood"])
    y = model2.encode(df_clothes_model_2.loc[i]["description"])
    X = x.reshape(1, -1)
    Y = y.reshape(1, -1)
    df_clothes_model_2.loc[i]["mood_4_seduction"] = sklearn.metrics.pairwise.cosine_similarity(X,Y)

for i in range (len(df_clothes_model_2)) :
    x= model2.encode(df_mood.loc[26]["day_mood"])
    y = model2.encode(df_clothes_model_2.loc[i]["description"])
    X = x.reshape(1, -1)
    Y = y.reshape(1, -1)
    df_clothes_model_2.loc[i]["mood_26_fatigue_maison"] = sklearn.metrics.pairwise.cosine_similarity(X,Y)

for i in range (len(df_clothes_model_2)) :
    x= model2.encode(df_mood.loc[1]["day_mood"])
    y = model2.encode(df_clothes_model_2.loc[i]["description"])
    X = x.reshape(1, -1)
    Y = y.reshape(1, -1)
    df_clothes_model_2.loc[i]["mood_1_travail"] = sklearn.metrics.pairwise.cosine_similarity(X,Y)

for i in range (len(df_clothes)) :
    x= model2.encode(df_mood.loc[22]["day_mood"])
    y = model2.encode(df_clothes_model_2.loc[i]["description"])
    X = x.reshape(1, -1)
    Y = y.reshape(1, -1)
    df_clothes_model_2.loc[i]["mood_22_sorties_amis"] = sklearn.metrics.pairwise.cosine_similarity(X,Y)

for i in range (len(df_clothes_model_2)) :
    x= model2.encode(df_mood.loc[3]["day_mood"])
    y = model2.encode(df_clothes_model_2.loc[i]["description"])
    X = x.reshape(1, -1)
    Y = y.reshape(1, -1)
    df_clothes_model_2.loc[i]["mood_3_sorties_detente"] = sklearn.metrics.pairwise.cosine_similarity(X,Y)
df_clothes_model_2
# Out:
#      id_clothes   category                                        description  \
# 0      tshirt_1     tshirt  J'ai acheté ce tshirt pour les beaux jours, po...
# 1        pull_1       pull  J'ai acheté ce pull pour le porter en mi saiso...
# 2        pull_2       pull  J'aime le côté rock de ce pull. J'ai envie de ...
# 3       veste_1      veste  Je voulais un classique rock intemporel, que l...
# 4       gilet_1      gilet  J'aime le côté ethnique et loose de ce gilet. ...
# 5        robe_1       robe  J'ai acheté cette robe pour me sentir féminine...
# 6       veste_2      veste  Je voulais une veste en jean légère, apportant...
# 7       short_1      short  Je voulais un short en jean pour me sentir à l...
# 8      blouse_1     blouse  Je voulais une chemise classique mais conforta...
# 9      tshirt_2     tshirt  Je cherchais un tshirt avec capuche pour le cô...
# 10     blouse_2     blouse  J'ai acheté cette blouse pour avoir des tenues...
# ...

# %%
y_pred_mood_18_tristesse_model_2 = df_clothes_model_2.sort_values(by=['mood_18_tristesse'], ascending=False).head(4)["id_clothes"]
y_pred_mood_4_seduction_model_2 = df_clothes_model_2.sort_values(by=['mood_4_seduction'], ascending=False).head(4)["id_clothes"]
y_pred_mood_26_fatigue_maison_model_2 = df_clothes_model_2.sort_values(by=['mood_26_fatigue_maison'], ascending=False).head(4)["id_clothes"]
y_pred_mood_1_travail_model_2 = df_clothes_model_2.sort_values(by=['mood_1_travail'], ascending=False).head(4)["id_clothes"]
y_pred_mood_22_sorties_amis_model_2 = df_clothes_model_2.sort_values(by=['mood_22_sorties_amis'], ascending=False).head(4)["id_clothes"]
y_pred_mood_3_sorties_detente_model_2 = df_clothes_model_2.sort_values(by=['mood_3_sorties_detente'], ascending=False).head(4)["id_clothes"]

# %%
score_mood1_model_2 = 0
for i in (y_true_mood_1_travail.index[1:]) :
    x = y_true_mood_1_travail[1:][i]
    for e in (y_pred_mood_1_travail_model_2.index) :
        if x == y_pred_mood_1_travail_model_2[e] :
            score_mood1_model_2 = score_mood1_model_2+1
print(score_mood1_model_2)
# Out:
# 2

# %%
score_mood4_model_2 = 0
for i in (y_true_mood_4_seduction.index[1:]) :
    x = y_true_mood_4_seduction[1:][i]
    for e in (y_pred_mood_4_seduction_model_2.index) :
        if x == y_pred_mood_4_seduction_model_2[e] :
            score_mood4_model_2 = score_mood4_model_2+1
print(score_mood4_model_2)
# Out:
# 1

# %%
score_mood18_model_2 = 0
for i in (y_true_mood_18_tristesse.index[1:]) :
    x = y_true_mood_18_tristesse[1:][i]
    for e in (y_pred_mood_18_tristesse_model_2.index) :
        if x == y_pred_mood_18_tristesse_model_2[e] :
            score_mood18_model_2 = score_mood18_model_2+1
print(score_mood18_model_2)
# Out:
# 0

# %%
score_mood26_model_2 = 0
for i in (y_true_mood_26_fatigue_maison.index[1:]) :
    x = y_true_mood_26_fatigue_maison[1:][i]
    for e in (y_pred_mood_26_fatigue_maison_model_2.index) :
        if x == y_pred_mood_26_fatigue_maison_model_2[e] :
            score_mood26_model_2 = score_mood26_model_2+1
print(score_mood26_model_2)
# Out:
# 0

# %%
score_mood22_model_2 = 0
for i in (y_true_mood_22_sorties_amis.index[1:]) :
    x = y_true_mood_22_sorties_amis[1:][i]
    for e in (y_pred_mood_22_sorties_amis_model_2.index) :
        if x == y_pred_mood_22_sorties_amis_model_2[e] :
            score_mood22_model_2 = score_mood22_model_2+1
print(score_mood22_model_2)
# Out:
# 2

# %%
score_mood3_model_2 = 0
for i in (y_true_mood_3_sorties_detente.index[1:]) :
    x = y_true_mood_3_sorties_detente[1:][i]
    for e in (y_pred_mood_3_sorties_detente_model_2.index) :
        if x == y_pred_mood_3_sorties_detente_model_2[e] :
            score_mood3_model_2 = score_mood3_model_2+1
print(score_mood3_model_2)
# Out:
# 1

# %%
score_total_mode2 = (score_mood3_model_2 + score_mood22_model_2 +score_mood26_model_2 +score_mood18_model_2 +score_mood4_model_2 +score_mood1_model_2)/24
score_total_mode2
# Out:
# 0.25

# %% [markdown]
# ### Model 3

# %%
model3 = SentenceTransformer("distiluse-base-multilingual-cased-v2")

# %%
df_clothes_model_3 = pd.read_excel("./Dataset/Clothes_table.xlsx")
df_clothes_model_3[[[[[["mood_18_tristesse", "mood_4_seduction", "mood_26_fatigue_maison", "mood_1_travail", "mood_22_sorties_amis" ,"mood_3_sorties_detente"]]]]]] = ""

# %%
for i in range (len(df_clothes_model_3)) :
    x= model3.encode(df_mood.loc[18]["day_mood"])
    y = model3.encode(df_clothes_model_3.loc[i]["description"])
    X = x.reshape(1, -1)
    Y = y.reshape(1, -1)
    df_clothes_model_3.loc[i]["mood_18_tristesse"] = sklearn.metrics.pairwise.cosine_similarity(X,Y)

for i in range (len(df_clothes_model_3)) :
    x= model3.encode(df_mood.loc[4]["day_mood"])
    y = model3.encode(df_clothes_model_3.loc[i]["description"])
    X = x.reshape(1, -1)
    Y = y.reshape(1, -1)
    df_clothes_model_3.loc[i]["mood_4_seduction"] = sklearn.metrics.pairwise.cosine_similarity(X,Y)

for i in range (len(df_clothes_model_3)) :
    x= model3.encode(df_mood.loc[26]["day_mood"])
    y = model3.encode(df_clothes_model_3.loc[i]["description"])
    X = x.reshape(1, -1)
    Y = y.reshape(1, -1)
    df_clothes_model_3.loc[i]["mood_26_fatigue_maison"] = sklearn.metrics.pairwise.cosine_similarity(X,Y)

for i in range (len(df_clothes_model_3)) :
    x= model3.encode(df_mood.loc[1]["day_mood"])
    y = model3.encode(df_clothes_model_3.loc[i]["description"])
    X = x.reshape(1, -1)
    Y = y.reshape(1, -1)
    df_clothes_model_3.loc[i]["mood_1_travail"] = sklearn.metrics.pairwise.cosine_similarity(X,Y)

for i in range (len(df_clothes_model_3)) :
    x= model3.encode(df_mood.loc[22]["day_mood"])
    y = model3.encode(df_clothes_model_3.loc[i]["description"])
    X = x.reshape(1, -1)
    Y = y.reshape(1, -1)
    df_clothes_model_3.loc[i]["mood_22_sorties_amis"] = sklearn.metrics.pairwise.cosine_similarity(X,Y)

for i in range (len(df_clothes_model_3)) :
    x= model3.encode(df_mood.loc[3]["day_mood"])
    y = model3.encode(df_clothes_model_3.loc[i]["description"])
    X = x.reshape(1, -1)
    Y = y.reshape(1, -1)
    df_clothes_model_3.loc[i]["mood_3_sorties_detente"] = sklearn.metrics.pairwise.cosine_similarity(X,Y)
df_clothes_model_3
# Out:
#      id_clothes   category                                        description  \
# 0      tshirt_1     tshirt  J'ai acheté ce tshirt pour les beaux jours, po...
# 1        pull_1       pull  J'ai acheté ce pull pour le porter en mi saiso...
# 2        pull_2       pull  J'aime le côté rock de ce pull. J'ai envie de ...
# 3       veste_1      veste  Je voulais un classique rock intemporel, que l...
# 4       gilet_1      gilet  J'aime le côté ethnique et loose de ce gilet. ...
# 5        robe_1       robe  J'ai acheté cette robe pour me sentir féminine...
# 6       veste_2      veste  Je voulais une veste en jean légère, apportant...
# 7       short_1      short  Je voulais un short en jean pour me sentir à l...
# 8      blouse_1     blouse  Je voulais une chemise classique mais conforta...
# 9      tshirt_2     tshirt  Je cherchais un tshirt avec capuche pour le cô...
# 10     blouse_2     blouse  J'ai acheté cette blouse pour avoir des tenues...
# ...

# %%
y_pred_mood_18_tristesse_model_3 = df_clothes_model_3.sort_values(by=['mood_18_tristesse'], ascending=False).head(4)["id_clothes"]
y_pred_mood_4_seduction_model_3 = df_clothes_model_3.sort_values(by=['mood_4_seduction'], ascending=False).head(4)["id_clothes"]
y_pred_mood_26_fatigue_maison_model_3 = df_clothes_model_3.sort_values(by=['mood_26_fatigue_maison'], ascending=False).head(4)["id_clothes"]
y_pred_mood_1_travail_model_3= df_clothes_model_3.sort_values(by=['mood_1_travail'], ascending=False).head(4)["id_clothes"]
y_pred_mood_22_sorties_amis_model_3= df_clothes_model_3.sort_values(by=['mood_22_sorties_amis'], ascending=False).head(4)["id_clothes"]
y_pred_mood_3_sorties_detente_model_3 = df_clothes_model_3.sort_values(by=['mood_3_sorties_detente'], ascending=False).head(4)["id_clothes"]

# %%
score_mood1_model_3 = 0
for i in (y_true_mood_1_travail.index[1:]) :
    x = y_true_mood_1_travail[1:][i]
    for e in (y_pred_mood_1_travail_model_3.index) :
        if x == y_pred_mood_1_travail_model_3[e] :
            score_mood1_model_3 = score_mood1_model_3+1
print(score_mood1_model_3)
# Out:
# 3

# %%
score_mood4_model_3 = 0
for i in (y_true_mood_4_seduction.index[1:]) :
    x = y_true_mood_4_seduction[1:][i]
    for e in (y_pred_mood_4_seduction_model_3.index) :
        if x == y_pred_mood_4_seduction_model_3[e] :
            score_mood4_model_3 = score_mood4_model_3+1
print(score_mood4_model_3)
# Out:
# 0

# %%
score_mood18_model_3 = 0
for i in (y_true_mood_18_tristesse.index[1:]) :
    x = y_true_mood_18_tristesse[1:][i]
    for e in (y_pred_mood_18_tristesse_model_3.index) :
        if x == y_pred_mood_18_tristesse_model_3[e] :
            score_mood18_model_3 = score_mood18_model_3+1
print(score_mood18_model_3)
# Out:
# 0

# %%
score_mood26_model_3 = 0
for i in (y_true_mood_26_fatigue_maison.index[1:]) :
    x = y_true_mood_26_fatigue_maison[1:][i]
    for e in (y_pred_mood_26_fatigue_maison_model_3.index) :
        if x == y_pred_mood_26_fatigue_maison_model_3[e] :
            score_mood26_model_3 = score_mood26_model_3+1
print(score_mood26_model_3)
# Out:
# 1

# %%
score_mood22_model_3 = 0
for i in (y_true_mood_22_sorties_amis.index[1:]) :
    x = y_true_mood_22_sorties_amis[1:][i]
    for e in (y_pred_mood_22_sorties_amis_model_3.index) :
        if x == y_pred_mood_22_sorties_amis_model_3[e] :
            score_mood22_model_3 = score_mood22_model_3+1
print(score_mood22_model_3)
# Out:
# 2

# %%
score_mood3_model_3 = 0
for i in (y_true_mood_3_sorties_detente.index[1:]) :
    x = y_true_mood_3_sorties_detente[1:][i]
    for e in (y_pred_mood_3_sorties_detente_model_3.index) :
        if x == y_pred_mood_3_sorties_detente_model_3[e] :
            score_mood3_model_3 = score_mood3_model_3+1
print(score_mood3_model_3)
# Out:
# 1

# %%
score_total_model_3 = (score_mood3_model_3 + score_mood22_model_3 +score_mood26_model_3 +score_mood18_model_3 +score_mood4_model_3 +score_mood1_model_3)/24
score_total_model_3
# Out:
# 0.2916666666666667

# %% [markdown]
# ### Model 4

# %%
model4 = SentenceTransformer("paraphrase-multilingual-MiniLM-L12-v2")

# %%
df_clothes_model_4 = pd.read_excel("./Dataset/Clothes_table.xlsx")
df_clothes_model_4[[[[[["mood_18_tristesse", "mood_4_seduction", "mood_26_fatigue_maison", "mood_1_travail", "mood_22_sorties_amis" ,"mood_3_sorties_detente"]]]]]] = ""

# %%
for i in range (len(df_clothes_model_4)) :
    x= model4.encode(df_mood.loc[18]["day_mood"])
    y = model4.encode(df_clothes_model_4.loc[i]["description"])
    X = x.reshape(1, -1)
    Y = y.reshape(1, -1)
    df_clothes_model_4.loc[i]["mood_18_tristesse"] = sklearn.metrics.pairwise.cosine_similarity(X,Y)

for i in range (len(df_clothes_model_4)) :
    x= model4.encode(df_mood.loc[4]["day_mood"])
    y = model4.encode(df_clothes_model_4.loc[i]["description"])
    X = x.reshape(1, -1)
    Y = y.reshape(1, -1)
    df_clothes_model_4.loc[i]["mood_4_seduction"] = sklearn.metrics.pairwise.cosine_similarity(X,Y)

for i in range (len(df_clothes_model_4)) :
    x= model4.encode(df_mood.loc[26]["day_mood"])
    y = model4.encode(df_clothes_model_4.loc[i]["description"])
    X = x.reshape(1, -1)
    Y = y.reshape(1, -1)
    df_clothes_model_4.loc[i]["mood_26_fatigue_maison"] = sklearn.metrics.pairwise.cosine_similarity(X,Y)

for i in range (len(df_clothes_model_4)) :
    x= model4.encode(df_mood.loc[1]["day_mood"])
    y = model4.encode(df_clothes_model_4.loc[i]["description"])
    X = x.reshape(1, -1)
    Y = y.reshape(1, -1)
    df_clothes_model_4.loc[i]["mood_1_travail"] = sklearn.metrics.pairwise.cosine_similarity(X,Y)

for i in range (len(df_clothes_model_4)) :
    x= model4.encode(df_mood.loc[22]["day_mood"])
    y = model4.encode(df_clothes_model_4.loc[i]["description"])
    X = x.reshape(1, -1)
    Y = y.reshape(1, -1)
    df_clothes_model_4.loc[i]["mood_22_sorties_amis"] = sklearn.metrics.pairwise.cosine_similarity(X,Y)

for i in range (len(df_clothes_model_4)) :
    x= model4.encode(df_mood.loc[3]["day_mood"])
    y = model4.encode(df_clothes_model_4.loc[i]["description"])
    X = x.reshape(1, -1)
    Y = y.reshape(1, -1)
    df_clothes_model_4.loc[i]["mood_3_sorties_detente"] = sklearn.metrics.pairwise.cosine_similarity(X,Y)
df_clothes_model_4
# Out:
#      id_clothes   category                                        description  \
# 0      tshirt_1     tshirt  J'ai acheté ce tshirt pour les beaux jours, po...
# 1        pull_1       pull  J'ai acheté ce pull pour le porter en mi saiso...
# 2        pull_2       pull  J'aime le côté rock de ce pull. J'ai envie de ...
# 3       veste_1      veste  Je voulais un classique rock intemporel, que l...
# 4       gilet_1      gilet  J'aime le côté ethnique et loose de ce gilet. ...
# 5        robe_1       robe  J'ai acheté cette robe pour me sentir féminine...
# 6       veste_2      veste  Je voulais une veste en jean légère, apportant...
# 7       short_1      short  Je voulais un short en jean pour me sentir à l...
# 8      blouse_1     blouse  Je voulais une chemise classique mais conforta...
# 9      tshirt_2     tshirt  Je cherchais un tshirt avec capuche pour le cô...
# 10     blouse_2     blouse  J'ai acheté cette blouse pour avoir des tenues...
# ...

# %%
y_pred_mood_18_tristesse_model_4 = df_clothes_model_4.sort_values(by=['mood_18_tristesse'], ascending=False).head(4)["id_clothes"]
y_pred_mood_4_seduction_model_4 = df_clothes_model_4.sort_values(by=['mood_4_seduction'], ascending=False).head(4)["id_clothes"]
y_pred_mood_26_fatigue_maison_model_4 = df_clothes_model_4.sort_values(by=['mood_26_fatigue_maison'], ascending=False).head(4)["id_clothes"]
y_pred_mood_1_travail_model_4= df_clothes_model_4.sort_values(by=['mood_1_travail'], ascending=False).head(4)["id_clothes"]
y_pred_mood_22_sorties_amis_model_4= df_clothes_model_4.sort_values(by=['mood_22_sorties_amis'], ascending=False).head(4)["id_clothes"]
y_pred_mood_3_sorties_detente_model_4 = df_clothes_model_4.sort_values(by=['mood_3_sorties_detente'], ascending=False).head(4)["id_clothes"]

# %%
score_mood1_model_4 = 0
for i in (y_true_mood_1_travail.index[1:]) :
    x = y_true_mood_1_travail[1:][i]
    for e in (y_pred_mood_1_travail_model_4.index) :
        if x == y_pred_mood_1_travail_model_4[e] :
            score_mood1_model_4 = score_mood1_model_4+1
print(score_mood1_model_4)
# Out:
# 1

# %%
score_mood4_model_4 = 0
for i in (y_true_mood_4_seduction.index[1:]) :
    x = y_true_mood_4_seduction[1:][i]
    for e in (y_pred_mood_4_seduction_model_4.index) :
        if x == y_pred_mood_4_seduction_model_4[e] :
            score_mood4_model_4 = score_mood4_model_4+1
print(score_mood4_model_4)
# Out:
# 1

# %%
score_mood18_model_4 = 0
for i in (y_true_mood_18_tristesse.index[1:]) :
    x = y_true_mood_18_tristesse[1:][i]
    for e in (y_pred_mood_18_tristesse_model_4.index) :
        if x == y_pred_mood_18_tristesse_model_4[e] :
            score_mood18_model_4 = score_mood18_model_4+1
print(score_mood18_model_4)
# Out:
# 0

# %%
score_mood26_model_4 = 0
for i in (y_true_mood_26_fatigue_maison.index[1:]) :
    x = y_true_mood_26_fatigue_maison[1:][i]
    for e in (y_pred_mood_26_fatigue_maison_model_4.index) :
        if x == y_pred_mood_26_fatigue_maison_model_4[e] :
            score_mood26_model_4 = score_mood26_model_4+1
print(score_mood26_model_4)
# Out:
# 3

# %%
score_mood22_model_4 = 0
for i in (y_true_mood_22_sorties_amis.index[1:]) :
    x = y_true_mood_22_sorties_amis[1:][i]
    for e in (y_pred_mood_22_sorties_amis_model_4.index) :
        if x == y_pred_mood_22_sorties_amis_model_4[e] :
            score_mood22_model_4 = score_mood22_model_4+1
print(score_mood22_model_4)
# Out:
# 1

# %%
score_mood3_model_4 = 0
for i in (y_true_mood_3_sorties_detente.index[1:]) :
    x = y_true_mood_3_sorties_detente[1:][i]
    for e in (y_pred_mood_3_sorties_detente_model_4.index) :
        if x == y_pred_mood_3_sorties_detente_model_4[e] :
            score_mood3_model_4 = score_mood3_model_4+1
print(score_mood3_model_4)
# Out:
# 1

# %%
score_total_model_4 = (score_mood3_model_4 + score_mood22_model_4 +score_mood26_model_4 +score_mood18_model_4 +score_mood4_model_4 +score_mood1_model_4)/24
score_total_model_4
# Out:
# 0.2916666666666667

# %% [markdown]
# ### Model 5

# %%
model5 = SentenceTransformer("paraphrase-multilingual-mpnet-base-v2")

# %%
df_clothes_model_5 = pd.read_excel("./Dataset/Clothes_table.xlsx")
df_clothes_model_5[[[[[["mood_18_tristesse", "mood_4_seduction", "mood_26_fatigue_maison", "mood_1_travail", "mood_22_sorties_amis" ,"mood_3_sorties_detente"]]]]]] = ""

# %%
for i in range (len(df_clothes_model_5)) :
    x= model5.encode(df_mood.loc[18]["day_mood"])
    y = model5.encode(df_clothes_model_5.loc[i]["description"])
    X = x.reshape(1, -1)
    Y = y.reshape(1, -1)
    df_clothes_model_5.loc[i]["mood_18_tristesse"] = sklearn.metrics.pairwise.cosine_similarity(X,Y)

for i in range (len(df_clothes_model_5)) :
    x= model5.encode(df_mood.loc[4]["day_mood"])
    y = model5.encode(df_clothes_model_5.loc[i]["description"])
    X = x.reshape(1, -1)
    Y = y.reshape(1, -1)
    df_clothes_model_5.loc[i]["mood_4_seduction"] = sklearn.metrics.pairwise.cosine_similarity(X,Y)

for i in range (len(df_clothes_model_5)) :
    x= model5.encode(df_mood.loc[26]["day_mood"])
    y = model5.encode(df_clothes_model_5.loc[i]["description"])
    X = x.reshape(1, -1)
    Y = y.reshape(1, -1)
    df_clothes_model_5.loc[i]["mood_26_fatigue_maison"] = sklearn.metrics.pairwise.cosine_similarity(X,Y)

for i in range (len(df_clothes_model_5)) :
    x= model5.encode(df_mood.loc[1]["day_mood"])
    y = model5.encode(df_clothes_model_5.loc[i]["description"])
    X = x.reshape(1, -1)
    Y = y.reshape(1, -1)
    df_clothes_model_5.loc[i]["mood_1_travail"] = sklearn.metrics.pairwise.cosine_similarity(X,Y)

for i in range (len(df_clothes_model_5)) :
    x= model5.encode(df_mood.loc[22]["day_mood"])
    y = model5.encode(df_clothes_model_5.loc[i]["description"])
    X = x.reshape(1, -1)
    Y = y.reshape(1, -1)
    df_clothes_model_5.loc[i]["mood_22_sorties_amis"] = sklearn.metrics.pairwise.cosine_similarity(X,Y)

for i in range (len(df_clothes_model_5)) :
    x= model5.encode(df_mood.loc[3]["day_mood"])
    y = model5.encode(df_clothes_model_5.loc[i]["description"])
    X = x.reshape(1, -1)
    Y = y.reshape(1, -1)
    df_clothes_model_5.loc[i]["mood_3_sorties_detente"] = sklearn.metrics.pairwise.cosine_similarity(X,Y)
df_clothes_model_5
# Out:
#      id_clothes   category                                        description  \
# 0      tshirt_1     tshirt  J'ai acheté ce tshirt pour les beaux jours, po...
# 1        pull_1       pull  J'ai acheté ce pull pour le porter en mi saiso...
# 2        pull_2       pull  J'aime le côté rock de ce pull. J'ai envie de ...
# 3       veste_1      veste  Je voulais un classique rock intemporel, que l...
# 4       gilet_1      gilet  J'aime le côté ethnique et loose de ce gilet. ...
# 5        robe_1       robe  J'ai acheté cette robe pour me sentir féminine...
# 6       veste_2      veste  Je voulais une veste en jean légère, apportant...
# 7       short_1      short  Je voulais un short en jean pour me sentir à l...
# 8      blouse_1     blouse  Je voulais une chemise classique mais conforta...
# 9      tshirt_2     tshirt  Je cherchais un tshirt avec capuche pour le cô...
# 10     blouse_2     blouse  J'ai acheté cette blouse pour avoir des tenues...
# ...

# %%
y_pred_mood_18_tristesse_model_5 = df_clothes_model_5.sort_values(by=['mood_18_tristesse'], ascending=False).head(4)["id_clothes"]
y_pred_mood_4_seduction_model_5 = df_clothes_model_5.sort_values(by=['mood_4_seduction'], ascending=False).head(4)["id_clothes"]
y_pred_mood_26_fatigue_maison_model_5 = df_clothes_model_5.sort_values(by=['mood_26_fatigue_maison'], ascending=False).head(4)["id_clothes"]
y_pred_mood_1_travail_model_5= df_clothes_model_5.sort_values(by=['mood_1_travail'], ascending=False).head(4)["id_clothes"]
y_pred_mood_22_sorties_amis_model_5= df_clothes_model_5.sort_values(by=['mood_22_sorties_amis'], ascending=False).head(4)["id_clothes"]
y_pred_mood_3_sorties_detente_model_5 = df_clothes_model_5.sort_values(by=['mood_3_sorties_detente'], ascending=False).head(4)["id_clothes"]

# %%
score_mood1_model_5 = 0
for i in (y_true_mood_1_travail.index[1:]) :
    x = y_true_mood_1_travail[1:][i]
    for e in (y_pred_mood_1_travail_model_5.index) :
        if x == y_pred_mood_1_travail_model_5[e] :
            score_mood1_model_5 = score_mood1_model_5+1
print(score_mood1_model_5)
# Out:
# 1

# %%
score_mood4_model_5 = 0
for i in (y_true_mood_4_seduction.index[1:]) :
    x = y_true_mood_4_seduction[1:][i]
    for e in (y_pred_mood_4_seduction_model_5.index) :
        if x == y_pred_mood_4_seduction_model_5[e] :
            score_mood4_model_5 = score_mood4_model_5+1
print(score_mood4_model_5)
# Out:
# 3

# %%
score_mood18_model_5 = 0
for i in (y_true_mood_18_tristesse.index[1:]) :
    x = y_true_mood_18_tristesse[1:][i]
    for e in (y_pred_mood_18_tristesse_model_5.index) :
        if x == y_pred_mood_18_tristesse_model_5[e] :
            score_mood18_model_5 = score_mood18_model_5+1
print(score_mood18_model_5)
# Out:
# 0

# %%
score_mood26_model_5 = 0
for i in (y_true_mood_26_fatigue_maison.index[1:]) :
    x = y_true_mood_26_fatigue_maison[1:][i]
    for e in (y_pred_mood_26_fatigue_maison_model_5.index) :
        if x == y_pred_mood_26_fatigue_maison_model_5[e] :
            score_mood26_model_5 = score_mood26_model_5+1
print(score_mood26_model_5)
# Out:
# 2

# %%
score_mood22_model_5 = 0
for i in (y_true_mood_22_sorties_amis.index[1:]) :
    x = y_true_mood_22_sorties_amis[1:][i]
    for e in (y_pred_mood_22_sorties_amis_model_5.index) :
        if x == y_pred_mood_22_sorties_amis_model_5[e] :
            score_mood22_model_5 = score_mood22_model_5+1
print(score_mood22_model_5)
# Out:
# 1

# %%
score_mood3_model_5 = 0
for i in (y_true_mood_3_sorties_detente.index[1:]) :
    x = y_true_mood_3_sorties_detente[1:][i]
    for e in (y_pred_mood_3_sorties_detente_model_5.index) :
        if x == y_pred_mood_3_sorties_detente_model_5[e] :
            score_mood3_model_5 = score_mood3_model_5+1
print(score_mood3_model_5)
# Out:
# 1

# %%
score_total_model_5 = (score_mood3_model_5 + score_mood22_model_5 +score_mood26_model_5 +score_mood18_model_5 +score_mood4_model_5 +score_mood1_model_5)/24
score_total_model_5
# Out:
# 0.3333333333333333
